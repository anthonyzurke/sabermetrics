# %% [markdown]
# # Table of Contents
#
# - [Libraries](#Libraries)
# - [Data](#Data)
# - [Data Cleaning](#Data-Cleaning)
# - [EDA](#EDA)
# - [Visuals](#Visuals)

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
df = pd.read_csv('../datasets/mlb_pitch_stats_19_21_cleaned.csv')
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
print(df.shape)
df.head()
# Out:
# (704, 88)
#     last_name  first_name  player_id  year  age     ip   bf   ab    h    k%  \
# 0  Wainwright        Adam     425794  2021   40  196.1  784  725  157  21.6
# 1     Greinke        Zack     425844  2021   38  164.2  670  626  157  17.0
# 2     Santana       Ervin     429722  2021   39   61.1  255  232   58  18.8
# 3       Petit    Yusmeiro     433589  2021   37   72.1  290  273   63  12.4
# 4      Jansen      Kenley     445276  2021   34   61.2  250  210   33  29.6
#
#    ...  cb_vb  cb_brk  cb_velo_range   cu%  cu_velo  cu_spinrate  cu_hb  \
# 0  ...  -66.4    22.3            1.6  22.2     85.0       2408.0    6.3
# 1  ...  -64.9    15.6            2.2   NaN      NaN          NaN    NaN
# 2  ...    NaN     NaN            NaN   NaN      NaN          NaN    NaN
# 3  ...  -48.8    10.7            1.8  23.3     84.5       2133.0   -1.1
# 4  ...    NaN     NaN            NaN  57.1     92.5       2689.0    7.3
#
#    cu_vb  cu_brk  cu_velo_range
# 0  -31.0     9.5            1.6
# 1    NaN     NaN            NaN
# 2    NaN     NaN            NaN
# 3  -21.1    17.3            1.3
# 4  -14.4    19.2            1.9
#
# [5 rows x 88 columns]

# %%
df2 = pd.read_csv('../datasets/mlb_pitch_stats_20_cleaned.csv')
df2.drop(['Unnamed: 0'], axis = 1, inplace = True)
print(df2.shape)
df2.head()
# Out:
# (368, 88)
#     last_name  first_name  player_id  year  age    ip   bf   ab   h    k%  \
# 0  Wainwright        Adam     425794  2020   39  65.2  262  244  54  20.6
# 1     Greinke        Zack     425844  2020   37  67.0  273  262  67  24.5
# 2       Petit    Yusmeiro     433589  2020   36  21.2   88   82  19  19.3
# 3     Sanchez      Anibal     434671  2020   36  53.0  245  224  70  17.6
# 4      Rondon      Hector     444468  2020   32  20.0   97   84  25  23.7
#
#    ...  cb_vb  cb_brk  cb_velo_range   cu%  cu_velo  cu_spinrate  cu_hb  \
# 0  ...  -65.5    22.0            1.6  22.9     85.0       2343.0    6.0
# 1  ...  -66.6    15.4            2.3   NaN      NaN          NaN    NaN
# 2  ...  -50.4    13.3            1.4  28.6     84.4       2133.0    0.2
# 3  ...  -48.6     4.7            1.6  21.0     87.3       2189.0    0.7
# 4  ...    NaN     NaN            NaN   NaN      NaN          NaN    NaN
#
#    cu_vb  cu_brk  cu_velo_range
# 0  -31.3     8.9            1.5
# 1    NaN     NaN            NaN
# 2  -22.7    15.6            1.2
# 3  -23.4    12.5            2.2
# 4    NaN     NaN            NaN
#
# [5 rows x 88 columns]

# %% [markdown]
# ### Concat both datasets

# %%
pitch_data = pd.concat([df, df2])
print(pitch_data.shape)
pitch_data.head()
# Out:
# (1072, 88)
#     last_name  first_name  player_id  year  age     ip   bf   ab    h    k%  \
# 0  Wainwright        Adam     425794  2021   40  196.1  784  725  157  21.6
# 1     Greinke        Zack     425844  2021   38  164.2  670  626  157  17.0
# 2     Santana       Ervin     429722  2021   39   61.1  255  232   58  18.8
# 3       Petit    Yusmeiro     433589  2021   37   72.1  290  273   63  12.4
# 4      Jansen      Kenley     445276  2021   34   61.2  250  210   33  29.6
#
#    ...  cb_vb  cb_brk  cb_velo_range   cu%  cu_velo  cu_spinrate  cu_hb  \
# 0  ...  -66.4    22.3            1.6  22.2     85.0       2408.0    6.3
# 1  ...  -64.9    15.6            2.2   NaN      NaN          NaN    NaN
# 2  ...    NaN     NaN            NaN   NaN      NaN          NaN    NaN
# 3  ...  -48.8    10.7            1.8  23.3     84.5       2133.0   -1.1
# 4  ...    NaN     NaN            NaN  57.1     92.5       2689.0    7.3
#
#    cu_vb  cu_brk  cu_velo_range
# 0  -31.0     9.5            1.6
# 1    NaN     NaN            NaN
# 2    NaN     NaN            NaN
# 3  -21.1    17.3            1.3
# 4  -14.4    19.2            1.9
#
# [5 rows x 88 columns]

# %%
data = pitch_data.copy()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check Nulls and dtypes

# %%
pitch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1072 entries, 0 to 367
# Data columns (total 88 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   last_name         1072 non-null   object
#  1    first_name       1072 non-null   object
#  2   player_id         1072 non-null   int64
#  3   year              1072 non-null   int64
#  4   age               1072 non-null   int64
#  5   ip                1072 non-null   float64
#  6   bf                1072 non-null   int64
#  7   ab                1072 non-null   int64
#  8   h                 1072 non-null   int64
#  9   k%                1072 non-null   float64
#  10  bb%               1072 non-null   float64
#  11  ba                1072 non-null   float64
#  12  slg%              1072 non-null   float64
#  13  obp%              1072 non-null   float64
#  14  ops               1072 non-null   float64
#  15  earned_runs       1072 non-null   int64
#  16  era               1072 non-null   float64
#  17  qual_start        1072 non-null   int64
#  18  cg                1072 non-null   int64
#  19  xba               1072 non-null   float64
#  20  xslg              1072 non-null   float64
#  21  woba              1072 non-null   float64
#  22  xwoba             1072 non-null   float64
#  23  xobp              1072 non-null   float64
#  24  wobacon           1072 non-null   float64
#  25  xwobacon          1072 non-null   float64
#  26  bacon             1072 non-null   float64
#  27  xbacon            1072 non-null   float64
#  28  ev_avg            1072 non-null   float64
#  29  la_avg            1072 non-null   float64
#  30  sweet_spot%       1072 non-null   float64
#  31  barrel%           1072 non-null   float64
#  32  solid_contact%    1072 non-null   float64
#  33  poor_weak%        1072 non-null   float64
#  34  hard_hit%         1072 non-null   float64
#  35  z_swing%          1072 non-null   float64
#  36  z_swing_miss%     1072 non-null   float64
#  37  oz_swing%         1072 non-null   float64
#  38  oz_swing_miss%    1072 non-null   float64
#  39  oz_contact%       1072 non-null   float64
#  40  out_zone%         1072 non-null   float64
#  41  pitch_count       1072 non-null   int64
#  42  z_contact%        1072 non-null   float64
#  43  in_zone%          1072 non-null   float64
#  44  edge%             1072 non-null   float64
#  45  whiff%            1072 non-null   float64
#  46  swing%            1072 non-null   float64
#  47  gb%               1072 non-null   float64
#  48  fb%               1072 non-null   float64
#  49  ld%               1072 non-null   float64
#  50  po%               1072 non-null   float64
#  51  throws            1072 non-null   object
#  52  n_pitches         1072 non-null   int64
#  53  4seam%            1029 non-null   float64
#  54  4seam_velo        1029 non-null   float64
#  55  4seam_spinrate    1029 non-null   float64
#  56  4seam_hb          1029 non-null   float64
#  57  4seam_vb          1029 non-null   float64
#  58  4seam_brk         1029 non-null   float64
#  59  4seam_velo_range  1020 non-null   float64
#  60  sl%               799 non-null    float64
#  61  sl_velo           799 non-null    float64
#  62  sl_spinrate       799 non-null    float64
#  63  sl_hb             799 non-null    float64
#  64  sl_vb             799 non-null    float64
#  65  sl_brk            799 non-null    float64
#  66  sl_velo_range     796 non-null    float64
#  67  ch%               858 non-null    float64
#  68  ch_velo           858 non-null    float64
#  69  ch_spinrate       858 non-null    float64
#  70  ch_hb             858 non-null    float64
#  71  ch_vb             858 non-null    float64
#  72  ch_brk            858 non-null    float64
#  73  ch_velo_range     841 non-null    float64
#  74  cb%               748 non-null    float64
#  75  cb_velo           748 non-null    float64
#  76  cb_spinrate       747 non-null    float64
#  77  cb_hb             748 non-null    float64
#  78  cb_vb             748 non-null    float64
#  79  cb_brk            748 non-null    float64
#  80  cb_velo_range     741 non-null    float64
#  81  cu%               351 non-null    float64
#  82  cu_velo           351 non-null    float64
#  83  cu_spinrate       351 non-null    float64
#  84  cu_hb             351 non-null    float64
#  85  cu_vb             351 non-null    float64
#  86  cu_brk            351 non-null    float64
#  87  cu_velo_range     345 non-null    float64
# dtypes: float64(74), int64(11), object(3)
# memory usage: 745.4+ KB

# %% [markdown]
# ### Nulls Imputation: 0

# %%
pitch_data.fillna(value = 0, inplace = True)
pitch_data[pitch_data.columns[pitch_data.isnull().any()]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ### Create expected OPS feature

# %%
pitch_data['xops'] = pitch_data['xobp'] + pitch_data['xslg']
data['xops'] = data['xobp'] + data['xslg']

# %% [markdown]
# ### Binarize Throws RHP: 1 LHP: 0

# %%
pitch_data['throws'] = pitch_data.throws.map({'R': 1, 'L': 0})

pitch_data['throws'].value_counts()
# Out:
# 1    776
# 0    296
# Name: throws, dtype: int64

# %% [markdown]
# ### Split Features into Categories for EDA

# %%
stats = pitch_data.iloc[:, :51].copy()
print('stats:', stats.shape)

pitch = pitch_data.iloc[:, 51:].copy()
print('pitch:', pitch.shape)


metrics = pitch_data.iloc[:, 4:26].copy()
print('metrics:', metrics.shape)

adv_metrics = pitch_data.iloc[:, 27:49].copy()
print('adv_metrics:', adv_metrics.shape)

velo = pitch_data[['4seam_velo', 'sl_velo', 
           'ch_velo', 'cb_velo', 
           'cu_velo', '4seam_velo_range', 
           'sl_velo_range', 'ch_velo_range', 
           'cb_velo_range', 'cu_velo_range']].copy()
print('velo:', velo.shape)
# 2seam_velo, 2seam_velo_range

spin = pitch_data[['4seam_spinrate', 'sl_spinrate', 
           'ch_spinrate', 'cb_spinrate', 
           'cu_spinrate', '4seam_hb', 
           '4seam_vb', 'sl_hb', 'sl_vb', 
           'ch_hb', 'ch_vb', 'cb_hb', 
           'cb_vb', 'cu_vb', 'cu_hb', ]].copy()

# '2seam_spinrate', '2seam_hb', '2seam_vb'

print('spin:', spin.shape)
# Out:
# stats: (1072, 51)
# pitch: (1072, 38)
# metrics: (1072, 22)
# adv_metrics: (1072, 22)
# velo: (1072, 10)
# spin: (1072, 15)

# %%
#pitch_data.to_csv('../datasets/mlb_pitch_stats_19_20_21.csv')

# %% [markdown]
# # EDA

# %%
pitch_data[pitch_data['year'] == 2019].describe()
# Out:
#            player_id    year         age          ip          bf          ab  \
# count     366.000000   366.0  366.000000  366.000000  366.000000  366.000000
# mean   568158.040984  2019.0   28.997268   96.956011  412.980874  371.562842
# std     67469.263609     0.0    3.550419   48.977186  202.871758  186.758639
# min    282332.000000  2019.0   21.000000   42.200000  200.000000  167.000000
# 25%    519141.750000  2019.0   26.000000   59.200000  253.000000  226.000000
# 50%    592542.500000  2019.0   29.000000   73.000000  317.000000  281.000000
# 75%    611504.750000  2019.0   31.000000  134.600000  577.000000  519.750000
# max    676606.000000  2019.0   42.000000  223.000000  911.000000  810.000000
#
#                 h          k%         bb%          ba  ...      cb_brk  \
# count  366.000000  366.000000  366.000000  366.000000  ...  366.000000
# mean    92.428962   23.696721    8.377596    0.247585  ...    9.289617
# std     48.295882    6.049249    2.666852    0.036038  ...    7.196952
# min     29.000000   10.900000    2.200000    0.123000  ...    0.000000
# 25%     54.000000   19.800000    6.425000    0.225000  ...    0.000000
# 50%     73.000000   22.450000    8.200000    0.249000  ...   10.600000
# 75%    127.750000   27.200000    9.700000    0.271000  ...   15.300000
# max    227.000000   47.800000   17.800000    0.351000  ...   23.700000
#
#        cb_velo_range         cu%     cu_velo  cu_spinrate       cu_hb  \
# count     366.000000  366.000000  366.000000   366.000000  366.000000
# mean        1.170765    7.059836   30.494809   799.901639    0.455464
# std         0.826276   13.555798   42.169485  1113.255700    1.993856
# min         0.000000    0.000000    0.000000     0.000000  -14.400000
# 25%         0.000000    0.000000    0.000000     0.000000    0.000000
# 50%         1.500000    0.000000    0.000000     0.000000    0.000000
# 75%         1.700000   12.100000   87.000000  2191.750000    0.000000
# max         4.000000   75.400000   94.600000  2928.000000    7.100000
#
#             cu_vb      cu_brk  cu_velo_range        xops
# count  366.000000  366.000000      366.00000  366.000000
# mean    -9.326776    3.246995        0.50082    0.721697
# std     13.205781    4.828588        0.73064    0.089971
# min    -40.600000    0.000000        0.00000    0.500000
# 25%    -24.000000    0.000000        0.00000    0.660500
# 50%      0.000000    0.000000        0.00000    0.719500
# 75%      0.000000    7.675000        1.30000    0.778750
# max      0.000000   21.900000        2.80000    1.119000
#
# [8 rows x 87 columns]

# %%
pitch_data[pitch_data['year'] == 2020].describe()
# Out:
#            player_id    year         age          ip          bf          ab  \
# count     368.000000   368.0  368.000000  368.000000  368.000000  368.000000
# mean   592352.225543  2020.0   28.766304   34.467391  147.260870  131.603261
# std     64964.779033     0.0    3.659895   16.876090   68.709771   63.882515
# min    425794.000000  2020.0   21.000000   16.000000   75.000000   63.000000
# 25%    546717.500000  2020.0   26.000000   21.200000   92.000000   81.000000
# 50%    605485.500000  2020.0   28.000000   26.200000  116.000000  103.000000
# 75%    642717.750000  2020.0   31.000000   46.400000  197.250000  178.000000
# max    685493.000000  2020.0   40.000000   84.000000  344.000000  316.000000
#
#                 h          k%         bb%         ba  ...      cb_brk  \
# count  368.000000  368.000000  368.000000  368.00000  ...  368.000000
# mean    31.527174   24.185598    9.063859    0.23794  ...    9.491848
# std     16.581376    6.865777    3.435664    0.04914  ...    7.417660
# min      8.000000    7.800000    2.500000    0.09000  ...    0.000000
# 25%     19.000000   19.375000    6.500000    0.20375  ...    0.000000
# 50%     26.000000   23.250000    8.600000    0.23650  ...   11.500000
# 75%     42.250000   28.625000   11.000000    0.27325  ...   15.800000
# max     85.000000   53.000000   21.300000    0.37800  ...   23.000000
#
#        cb_velo_range         cu%     cu_velo  cu_spinrate       cu_hb  \
# count     368.000000  368.000000  368.000000   368.000000  368.000000
# mean        1.055163    7.867935   28.776902   774.894022    0.363859
# std         0.750786   14.923757   41.453856  1122.314173    1.878234
# min         0.000000    0.000000    0.000000     0.000000   -6.600000
# 25%         0.000000    0.000000    0.000000     0.000000    0.000000
# 50%         1.400000    0.000000    0.000000     0.000000    0.000000
# 75%         1.600000    9.725000   86.500000  2218.750000    0.000000
# max         3.700000   81.100000   95.400000  2919.000000   10.300000
#
#             cu_vb      cu_brk  cu_velo_range        xops
# count  368.000000  368.000000     368.000000  368.000000
# mean    -8.907609    2.960598       0.481250    0.716948
# std     13.143996    4.544152       0.718727    0.110954
# min    -49.800000    0.000000       0.000000    0.379000
# 25%    -23.550000    0.000000       0.000000    0.633750
# 50%      0.000000    0.000000       0.000000    0.716000
# 75%      0.000000    7.125000       1.300000    0.789000
# max      0.000000   18.100000       3.300000    1.037000
#
# [8 rows x 87 columns]

# %%
pitch_data[pitch_data['year'] == 2021].describe()
# Out:
#            player_id    year         age          ip          bf          ab  \
# count     338.000000   338.0  338.000000  338.000000  338.000000  338.000000
# mean   596292.192308  2021.0   29.301775   88.911538  375.973373  337.446746
# std     65743.486437     0.0    3.739761   40.037838  164.828431  152.732224
# min    425794.000000  2021.0   22.000000   44.000000  200.000000  166.000000
# 25%    549451.750000  2021.0   26.000000   56.400000  239.000000  212.000000
# 50%    608340.500000  2021.0   29.000000   71.050000  302.500000  271.500000
# 75%    650641.250000  2021.0   32.000000  116.075000  494.500000  447.750000
# max    680686.000000  2021.0   41.000000  200.100000  800.000000  740.000000
#
#                 h          k%         bb%          ba  ...      cb_brk  \
# count  338.000000  338.000000  338.000000  338.000000  ...  338.000000
# mean    80.878698   23.987870    8.573077    0.237367  ...    9.369527
# std     39.678008    5.838982    2.771113    0.036753  ...    7.287336
# min     24.000000   11.800000    2.000000    0.129000  ...    0.000000
# 25%     48.000000   19.900000    6.500000    0.213000  ...    0.000000
# 50%     66.000000   23.400000    8.200000    0.235500  ...   10.700000
# 75%    113.750000   27.375000   10.200000    0.261000  ...   15.675000
# max    190.000000   45.100000   18.700000    0.335000  ...   27.000000
#
#        cb_velo_range         cu%     cu_velo  cu_spinrate       cu_hb  \
# count     338.000000  338.000000  338.000000   338.000000  338.000000
# mean        1.127219    6.723077   27.403846   725.505917    0.409763
# std         0.811691   13.528671   40.913990  1088.021233    1.718133
# min         0.000000    0.000000    0.000000     0.000000   -5.400000
# 25%         0.000000    0.000000    0.000000     0.000000    0.000000
# 50%         1.400000    0.000000    0.000000     0.000000    0.000000
# 75%         1.700000    7.675000   85.875000  2151.750000    0.000000
# max         4.300000   78.100000  100.200000  2872.000000    7.300000
#
#             cu_vb      cu_brk  cu_velo_range        xops
# count  338.000000  338.000000     338.000000  338.000000
# mean    -8.403254    2.881657       0.472781    0.701849
# std     12.808471    4.582118       0.721952    0.087526
# min    -41.800000    0.000000       0.000000    0.425000
# 25%    -23.450000    0.000000       0.000000    0.641500
# 50%      0.000000    0.000000       0.000000    0.700000
# 75%      0.000000    6.900000       1.300000    0.760000
# max      0.000000   19.200000       2.600000    0.916000
#
# [8 rows x 87 columns]

# %%
stats.describe()
# Out:
#            player_id         year          age           ip           bf  \
# count    1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean   585334.163246  2019.973881    29.013993    72.968284   310.095149
# std     67180.681177     0.810337     3.651585    46.964846   195.680155
# min    282332.000000  2019.000000    21.000000    16.000000    75.000000
# 25%    543243.000000  2019.000000    26.000000    43.175000   189.750000
# 50%    605136.500000  2020.000000    29.000000    60.000000   254.500000
# 75%    641816.000000  2021.000000    31.000000    90.400000   390.500000
# max    685493.000000  2021.000000    42.000000   223.000000   911.000000
#
#                 ab            h           k%          bb%           ba  ...  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000  ...
# mean    278.431903    67.880597    23.956343     8.674813     0.241052  ...
# std     179.153855    45.802531     6.276428     2.995060     0.041441  ...
# min      63.000000     8.000000     7.800000     2.000000     0.090000  ...
# 25%     166.000000    36.000000    19.600000     6.500000     0.213000  ...
# 50%     227.500000    54.000000    23.100000     8.300000     0.241000  ...
# 75%     352.000000    88.000000    27.700000    10.400000     0.269000  ...
# max     810.000000   227.000000    53.000000    21.300000     0.378000  ...
#
#        pitch_count   z_contact%     in_zone%        edge%       whiff%  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean   1214.529851    80.913806    48.256716    42.445802    26.447015
# std     758.612420     4.766129     3.482325     2.318879     5.518103
# min     272.000000    59.600000    36.300000    32.900000    13.400000
# 25%     722.750000    78.100000    46.000000    41.000000    22.600000
# 50%     997.500000    81.200000    48.300000    42.500000    26.000000
# 75%    1544.750000    84.200000    50.800000    43.925000    29.700000
# max    3687.000000    96.600000    60.800000    51.400000    51.800000
#
#             swing%          gb%          fb%          ld%          po%
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean     47.231063    44.044123    23.144963    25.496082     7.315672
# std       3.309581     8.568263     5.962893     4.532942     3.215883
# min      33.900000    13.600000     5.700000    12.500000     0.000000
# 25%      45.100000    38.000000    19.100000    22.600000     5.100000
# 50%      47.300000    43.950000    23.100000    25.100000     7.000000
# 75%      49.300000    49.700000    27.200000    27.900000     9.100000
# max      59.200000    76.700000    41.300000    43.400000    23.500000
#
# [8 rows x 49 columns]

# %%
pitch.describe()
# Out:
#             throws    n_pitches       4seam%   4seam_velo  4seam_spinrate  \
# count  1072.000000  1072.000000  1072.000000  1072.000000     1072.000000
# mean      0.723881  1207.961754    35.155410    89.592351     2180.055970
# std       0.447285   751.832608    20.596602    18.487592      471.390965
# min       0.000000   272.000000     0.000000     0.000000        0.000000
# 25%       0.000000   719.000000    18.775000    91.600000     2146.750000
# 50%       1.000000   994.000000    38.300000    93.400000     2264.000000
# 75%       1.000000  1544.750000    50.600000    94.800000     2373.500000
# max       1.000000  3686.000000    96.400000   100.600000     2783.000000
#
#           4seam_hb     4seam_vb    4seam_brk  4seam_velo_range          sl%  \
# count  1072.000000  1072.000000  1072.000000       1072.000000  1072.000000
# mean     -3.173694   -15.608769    16.855410          1.281903    18.281157
# std       7.382091     4.901611     4.161565          0.363083    15.859613
# min     -16.800000   -54.200000     0.000000          0.000000     0.000000
# 25%      -8.700000   -17.700000    16.000000          1.200000     0.000000
# 50%      -5.600000   -15.600000    17.900000          1.300000    17.850000
# 75%       1.200000   -13.700000    19.100000          1.500000    28.825000
# max      18.800000     0.000000    23.000000          2.500000    87.400000
#
#        ...       cb_brk  cb_velo_range          cu%      cu_velo  cu_spinrate  \
# count  ...  1072.000000    1072.000000  1072.000000  1072.000000  1072.000000
# mean   ...     9.384235       1.117351     7.231063    28.930504   767.860075
# std    ...     7.295460       0.797169    14.027337    41.511393  1107.889228
# min    ...     0.000000       0.000000     0.000000     0.000000     0.000000
# 25%    ...     0.000000       0.000000     0.000000     0.000000     0.000000
# 50%    ...    10.950000       1.400000     0.000000     0.000000     0.000000
# 75%    ...    15.700000       1.700000     9.350000    86.500000  2194.500000
# max    ...    27.000000       4.300000    81.100000   100.200000  2928.000000
#
#              cu_hb        cu_vb       cu_brk  cu_velo_range         xops
# count  1072.000000  1072.000000  1072.000000    1072.000000  1072.000000
# mean      0.409608    -8.891698     3.033489       0.485261     0.713809
# std       1.869229    13.053618     4.653281       0.723248     0.097250
# min     -14.400000   -49.800000     0.000000       0.000000     0.379000
# 25%       0.000000   -23.800000     0.000000       0.000000     0.646000
# 50%       0.000000     0.000000     0.000000       0.000000     0.711000
# 75%       0.000000     0.000000     7.225000       1.300000     0.777000
# max      10.300000     0.000000    21.900000       3.300000     1.119000
#
# [8 rows x 38 columns]

# %%
metrics.describe()
# Out:
#                age           ip           bf           ab            h  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean     29.013993    72.968284   310.095149   278.431903    67.880597
# std       3.651585    46.964846   195.680155   179.153855    45.802531
# min      21.000000    16.000000    75.000000    63.000000     8.000000
# 25%      26.000000    43.175000   189.750000   166.000000    36.000000
# 50%      29.000000    60.000000   254.500000   227.500000    54.000000
# 75%      31.000000    90.400000   390.500000   352.000000    88.000000
# max      42.000000   223.000000   911.000000   810.000000   227.000000
#
#                 k%          bb%           ba         slg%         obp%  ...  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000  ...
# mean     23.956343     8.674813     0.241052     0.408381     0.313243  ...
# std       6.276428     2.995060     0.041441     0.085314     0.040858  ...
# min       7.800000     2.000000     0.090000     0.157000     0.160000  ...
# 25%      19.600000     6.500000     0.213000     0.351000     0.286000  ...
# 50%      23.100000     8.300000     0.241000     0.406500     0.314000  ...
# 75%      27.700000    10.400000     0.269000     0.459250     0.341000  ...
# max      53.000000    21.300000     0.378000     0.759000     0.453000  ...
#
#                era   qual_start           cg          xba         xslg  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean      4.242201     3.468284     0.109142     0.237684     0.401076
# std       1.529310     5.315351     0.386792     0.033731     0.070624
# min       0.330000     0.000000     0.000000     0.108000     0.181000
# 25%       3.240000     0.000000     0.000000     0.216000     0.353000
# 50%       4.065000     0.000000     0.000000     0.239000     0.399000
# 75%       5.052500     5.000000     0.000000     0.261000     0.448000
# max      10.260000    26.000000     3.000000     0.339000     0.717000
#
#               woba        xwoba         xobp      wobacon     xwobacon
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean      0.310672     0.311649     0.312733     0.368159     0.369471
# std       0.044850     0.038085     0.035740     0.055898     0.040240
# min       0.164000     0.182000     0.179000     0.180000     0.236000
# 25%       0.280000     0.286000     0.289000     0.330750     0.342000
# 50%       0.310000     0.311000     0.312000     0.368000     0.368000
# 75%       0.339000     0.335250     0.337000     0.401000     0.396000
# max       0.470000     0.452000     0.444000     0.588000     0.523000
#
# [8 rows x 22 columns]

# %%
adv_metrics.describe()
# Out:
#             xbacon       ev_avg       la_avg  sweet_spot%      barrel%  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean      0.323672    88.558209    12.596642    33.031250     7.394030
# std       0.028985     1.749346     5.635236     4.723013     2.595856
# min       0.213000    81.700000    -9.300000    15.700000     0.000000
# 25%       0.306000    87.400000     9.100000    30.300000     5.600000
# 50%       0.325000    88.600000    12.600000    33.300000     7.200000
# 75%       0.342000    89.725000    16.400000    36.000000     9.000000
# max       0.417000    94.400000    33.400000    47.800000    20.000000
#
#        solid_contact%   poor_weak%    hard_hit%     z_swing%  z_swing_miss%  \
# count     1072.000000  1072.000000  1072.000000  1072.000000    1072.000000
# mean         5.969030     4.240299    37.377985    67.403731      18.549907
# std          2.104216     2.206221     5.416031     4.108387       4.837633
# min          0.000000     0.000000    14.000000    50.600000       3.400000
# 25%          4.600000     2.775000    33.800000    64.800000      15.200000
# 50%          5.800000     4.000000    37.500000    67.600000      18.100000
# 75%          7.200000     5.400000    40.625000    70.100000      21.400000
# max         13.700000    15.000000    56.400000    81.000000      40.000000
#
#        ...  oz_contact%    out_zone%  pitch_count   z_contact%     in_zone%  \
# count  ...  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean   ...    55.774534    51.743284  1214.529851    80.913806    48.256716
# std    ...     8.986669     3.482325   758.612420     4.766129     3.482325
# min    ...    25.500000    39.200000   272.000000    59.600000    36.300000
# 25%    ...    50.300000    49.200000   722.750000    78.100000    46.000000
# 50%    ...    56.500000    51.700000   997.500000    81.200000    48.300000
# 75%    ...    62.025000    54.000000  1544.750000    84.200000    50.800000
# max    ...    80.000000    63.700000  3687.000000    96.600000    60.800000
#
#              edge%       whiff%       swing%          gb%          fb%
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean     42.445802    26.447015    47.231063    44.044123    23.144963
# std       2.318879     5.518103     3.309581     8.568263     5.962893
# min      32.900000    13.400000    33.900000    13.600000     5.700000
# 25%      41.000000    22.600000    45.100000    38.000000    19.100000
# 50%      42.500000    26.000000    47.300000    43.950000    23.100000
# 75%      43.925000    29.700000    49.300000    49.700000    27.200000
# max      51.400000    51.800000    59.200000    76.700000    41.300000
#
# [8 rows x 22 columns]

# %%
velo.describe()
# Out:
#         4seam_velo      sl_velo      ch_velo      cb_velo      cu_velo  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean     89.592351    62.941884    68.391884    54.897388    28.930504
# std      18.487592    36.908771    34.289608    36.261250    41.511393
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      91.600000     0.000000    80.200000     0.000000     0.000000
# 50%      93.400000    83.400000    84.800000    77.000000     0.000000
# 75%      94.800000    86.000000    87.100000    80.225000    86.500000
# max     100.600000    92.500000    93.400000    87.200000   100.200000
#
#        4seam_velo_range  sl_velo_range  ch_velo_range  cb_velo_range  \
# count       1072.000000    1072.000000    1072.000000    1072.000000
# mean           1.281903       1.210634       1.155690       1.117351
# std            0.363083       0.763193       0.647732       0.797169
# min            0.000000       0.000000       0.000000       0.000000
# 25%            1.200000       0.000000       1.100000       0.000000
# 50%            1.300000       1.500000       1.400000       1.400000
# 75%            1.500000       1.700000       1.500000       1.700000
# max            2.500000       3.600000       3.100000       4.300000
#
#        cu_velo_range
# count    1072.000000
# mean        0.485261
# std         0.723248
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.300000
# max         3.300000

# %%
spin.describe()
# Out:
#        4seam_spinrate  sl_spinrate  ch_spinrate  cb_spinrate  cu_spinrate  \
# count     1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean      2180.055970  1798.548507  1420.745336  1730.012127   767.860075
# std        471.390965  1070.688736   746.033237  1165.820786  1107.889228
# min          0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2146.750000     0.000000  1431.500000     0.000000     0.000000
# 50%       2264.000000  2306.000000  1680.500000  2321.000000     0.000000
# 75%       2373.500000  2495.000000  1885.000000  2576.750000  2194.500000
# max       2783.000000  3270.000000  2852.000000  3349.000000  2928.000000
#
#           4seam_hb     4seam_vb        sl_hb        sl_vb        ch_hb  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean     -3.173694   -15.608769     2.139646   -27.686847    -4.455877
# std       7.382091     4.901611     5.889821    16.899896    11.392782
# min     -16.800000   -54.200000   -22.700000   -60.700000   -20.600000
# 25%      -8.700000   -17.700000     0.000000   -39.325000   -14.025000
# 50%      -5.600000   -15.600000     1.400000   -34.400000    -9.800000
# 75%       1.200000   -13.700000     5.100000     0.000000     0.000000
# max      18.800000     0.000000    22.800000     0.000000    20.400000
#
#              ch_vb        cb_hb        cb_vb        cu_vb        cu_hb
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000
# mean    -24.196362     2.887500   -37.605784    -8.891698     0.409608
# std      12.915164     7.459504    25.503077    13.053618     1.869229
# min     -55.200000   -26.000000   -78.900000   -49.800000   -14.400000
# 25%     -32.200000     0.000000   -56.100000   -23.800000     0.000000
# 50%     -28.400000     0.550000   -49.800000     0.000000     0.000000
# 75%     -23.200000     9.000000     0.000000     0.000000     0.000000
# max       0.000000    22.000000     0.000000     0.000000    10.300000

# %%
pitch.corr()
# Out:
#                     throws  n_pitches    4seam%  4seam_velo  4seam_spinrate  \
# throws            1.000000  -0.036324  0.002129    0.120776        0.115078
# n_pitches        -0.036324   1.000000 -0.014602   -0.002813       -0.003147
# 4seam%            0.002129  -0.014602  1.000000    0.375119        0.410760
# 4seam_velo        0.120776  -0.002813  0.375119    1.000000        0.950500
# 4seam_spinrate    0.115078  -0.003147  0.410760    0.950500        1.000000
# 4seam_hb         -0.871358   0.017684 -0.000661   -0.121925       -0.110822
# 4seam_vb          0.035180  -0.006378  0.063721   -0.581987       -0.523818
# 4seam_brk         0.039779   0.015177  0.487967    0.831607        0.826690
# 4seam_velo_range  0.023246   0.133403  0.292092    0.715232        0.670482
# sl%               0.109408  -0.089998 -0.007148    0.067912        0.073413
# sl_velo           0.088372   0.036350  0.082573    0.038285        0.053413
# sl_spinrate       0.091649   0.030323  0.077678    0.033477        0.075843
# sl_hb             0.636417   0.029247 -0.025766    0.049587        0.078641
# sl_vb            -0.034154  -0.014166 -0.065240   -0.007525       -0.031317
# sl_brk            0.055758   0.016552  0.031534   -0.009168        0.055059
# sl_velo_range     0.053741   0.092351  0.080750    0.052587        0.055768
# ch%              -0.135713   0.104953 -0.088892   -0.078809       -0.099897
# ch_velo          -0.051777   0.163790  0.007193    0.006900        0.003764
# ch_spinrate      -0.071516   0.146041 -0.011622   -0.010937        0.005776
# ch_hb            -0.851183   0.009367 -0.017552   -0.107392       -0.104125
# ch_vb             0.095003  -0.157604  0.110302    0.078691        0.084735
# ch_brk           -0.097639   0.167295  0.007775   -0.004475        0.003369
# ch_velo_range    -0.069985   0.224810 -0.000370   -0.004303       -0.010771
# cb%               0.006046   0.085527 -0.019180   -0.008909        0.018811
# cb_velo           0.001838   0.256972  0.027770    0.010873        0.050928
# cb_spinrate       0.015841   0.250574  0.026126    0.016023        0.075446
# cb_hb             0.703892   0.070450 -0.035384    0.087044        0.094130
# cb_vb             0.027141  -0.274509 -0.042302   -0.008248       -0.051285
# cb_brk            0.050656   0.216049  0.028553    0.005520        0.062825
# cb_velo_range    -0.022165   0.334200  0.052168    0.023725        0.058529
# cu%              -0.042190  -0.015644 -0.296404   -0.136154       -0.109949
# cu_velo          -0.024820   0.075767 -0.216305   -0.062977       -0.041108
# cu_spinrate      -0.011943   0.075057 -0.211564   -0.059599       -0.023570
# cu_hb             0.278906   0.006954 -0.042533   -0.005021        0.028869
# cu_vb             0.049168  -0.078407  0.203371    0.046543        0.023588
# cu_brk           -0.015382   0.084194 -0.197680   -0.103759       -0.074360
# cu_velo_range    -0.029910   0.094422 -0.203280   -0.054062       -0.031748
# xops             -0.003748   0.014941 -0.050360   -0.026849       -0.065794
#
#                   4seam_hb  4seam_vb  4seam_brk  4seam_velo_range       sl%  \
# throws           -0.871358  0.035180   0.039779          0.023246  0.109408
# n_pitches         0.017684 -0.006378   0.015177          0.133403 -0.089998
# 4seam%           -0.000661  0.063721   0.487967          0.292092 -0.007148
# 4seam_velo       -0.121925 -0.581987   0.831607          0.715232  0.067912
# 4seam_spinrate   -0.110822 -0.523818   0.826690          0.670482  0.073413
# 4seam_hb          1.000000 -0.029531  -0.079389         -0.023427 -0.099054
# 4seam_vb         -0.029531  1.000000  -0.285320         -0.481924 -0.028185
# 4seam_brk        -0.079389 -0.285320   1.000000          0.584033  0.001030
# 4seam_velo_range -0.023427 -0.481924   0.584033          1.000000  0.005525
# sl%              -0.099054 -0.028185   0.001030          0.005525  1.000000
# sl_velo          -0.091994  0.046612   0.010375          0.041183  0.677651
# sl_spinrate      -0.086916  0.038140   0.004698          0.033303  0.682340
# sl_hb            -0.508792 -0.009847  -0.007310         -0.002808  0.196383
# sl_vb             0.026893  0.013589   0.024834         -0.037563 -0.633030
# sl_brk           -0.047446 -0.035852  -0.028993          0.021343  0.517503
# sl_velo_range    -0.055981  0.029522   0.026522          0.125604  0.606882
# ch%               0.086476 -0.047818   0.016752          0.003893 -0.322347
# ch_velo           0.043196 -0.060209  -0.006899          0.100212 -0.107255
# ch_spinrate       0.055795 -0.067012  -0.003195          0.076429 -0.104423
# ch_hb             0.785926 -0.042173  -0.038599         -0.027388 -0.097830
# ch_vb            -0.077002  0.149513   0.089064         -0.060250  0.158559
# ch_brk            0.068991 -0.036560   0.048758          0.087989 -0.102936
# ch_velo_range     0.068493 -0.082979  -0.027038          0.162660 -0.123814
# cb%               0.017807  0.008764  -0.005202         -0.012888 -0.503087
# cb_velo           0.026845  0.040740   0.054784          0.092362 -0.407335
# cb_spinrate       0.023269  0.033044   0.053796          0.099264 -0.393255
# cb_hb            -0.568569 -0.001424   0.005743          0.073722 -0.021564
# cb_vb            -0.055085 -0.017277  -0.063165         -0.123344  0.384813
# cb_brk           -0.011212  0.022894   0.022429          0.100212 -0.340833
# cb_velo_range     0.050805  0.021323   0.052125          0.169963 -0.366414
# cu%               0.101040 -0.003754  -0.177675         -0.095539 -0.383051
# cu_velo           0.069157 -0.043901  -0.092980         -0.014894 -0.421915
# cu_spinrate       0.057215 -0.034761  -0.084812         -0.016993 -0.411038
# cu_hb            -0.142879  0.062796  -0.031132          0.002485 -0.116710
# cu_vb            -0.083683  0.070297   0.077595          0.001964  0.428205
# cu_brk            0.070628  0.004186  -0.093086         -0.045328 -0.385738
# cu_velo_range     0.069198 -0.042541  -0.077168          0.024335 -0.421625
# xops              0.021264 -0.126535  -0.056624          0.104675 -0.111618
#
#                   ...    cb_brk  cb_velo_range       cu%   cu_velo  \
# throws            ...  0.050656      -0.022165 -0.042190 -0.024820
# n_pitches         ...  0.216049       0.334200 -0.015644  0.075767
# 4seam%            ...  0.028553       0.052168 -0.296404 -0.216305
# 4seam_velo        ...  0.005520       0.023725 -0.136154 -0.062977
# 4seam_spinrate    ...  0.062825       0.058529 -0.109949 -0.041108
# 4seam_hb          ... -0.011212       0.050805  0.101040  0.069157
# 4seam_vb          ...  0.022894       0.021323 -0.003754 -0.043901
# 4seam_brk         ...  0.022429       0.052125 -0.177675 -0.092980
# 4seam_velo_range  ...  0.100212       0.169963 -0.095539 -0.014894
# sl%               ... -0.340833      -0.366414 -0.383051 -0.421915
# sl_velo           ... -0.231422      -0.245446 -0.366360 -0.388703
# sl_spinrate       ... -0.190102      -0.234105 -0.334239 -0.345622
# sl_hb             ...  0.051162       0.012193  0.002578  0.037832
# sl_vb             ...  0.214254       0.271330  0.293292  0.293108
# sl_brk            ... -0.048313      -0.152158 -0.172224 -0.133535
# sl_velo_range     ... -0.210798      -0.195472 -0.324825 -0.350209
# ch%               ...  0.013755       0.087921 -0.075690  0.020184
# ch_velo           ...  0.104372       0.166837 -0.073792 -0.006499
# ch_spinrate       ...  0.084285       0.136158 -0.072304  0.001583
# ch_hb             ... -0.055275       0.002126  0.097088  0.039769
# ch_vb             ... -0.099793      -0.148067  0.028122 -0.054286
# ch_brk            ...  0.094354       0.153092 -0.092154 -0.017537
# ch_velo_range     ...  0.129423       0.218248 -0.057389  0.001769
# cb%               ...  0.591481       0.542806  0.064158  0.105352
# cb_velo           ...  0.831251       0.917399  0.092190  0.185892
# cb_spinrate       ...  0.885721       0.906351  0.103666  0.192416
# cb_hb             ...  0.324675       0.238483  0.001991  0.080123
# cb_vb             ... -0.910442      -0.903842 -0.103700 -0.207679
# cb_brk            ...  1.000000       0.784680  0.106752  0.199054
# cb_velo_range     ...  0.784680       1.000000  0.076822  0.166291
# cu%               ...  0.106752       0.076822  1.000000  0.742219
# cu_velo           ...  0.199054       0.166291  0.742219  1.000000
# cu_spinrate       ...  0.210171       0.170569  0.743235  0.994007
# cu_hb             ...  0.126050       0.071334  0.286031  0.318529
# cu_vb             ... -0.211506      -0.172165 -0.709123 -0.970305
# cu_brk            ...  0.181146       0.161849  0.697233  0.938300
# cu_velo_range     ...  0.206084       0.192691  0.723524  0.959754
# xops              ...  0.101020       0.182267  0.017657  0.035899
#
#                   cu_spinrate     cu_hb     cu_vb    cu_brk  cu_velo_range  \
# throws              -0.011943  0.278906  0.049168 -0.015382      -0.029910
# n_pitches            0.075057  0.006954 -0.078407  0.084194       0.094422
# 4seam%              -0.211564 -0.042533  0.203371 -0.197680      -0.203280
# 4seam_velo          -0.059599 -0.005021  0.046543 -0.103759      -0.054062
# 4seam_spinrate      -0.023570  0.028869  0.023588 -0.074360      -0.031748
# 4seam_hb             0.057215 -0.142879 -0.083683  0.070628       0.069198
# 4seam_vb            -0.034761  0.062796  0.070297  0.004186      -0.042541
# 4seam_brk           -0.084812 -0.031132  0.077595 -0.093086      -0.077168
# 4seam_velo_range    -0.016993  0.002485  0.001964 -0.045328       0.024335
# sl%                 -0.411038 -0.116710  0.428205 -0.385738      -0.421625
# sl_velo             -0.377764 -0.129228  0.408573 -0.338729      -0.382210
# sl_spinrate         -0.328878 -0.098280  0.362028 -0.300661      -0.337184
# sl_hb                0.055278  0.287027 -0.020434  0.040352       0.048863
# sl_vb                0.281016  0.100486 -0.301617  0.257966       0.280807
# sl_brk              -0.111249  0.017807  0.123288 -0.124237      -0.104548
# sl_velo_range       -0.341728 -0.126450  0.366885 -0.301830      -0.332667
# ch%                  0.006075 -0.100633 -0.029103  0.034026       0.041319
# ch_velo             -0.009321 -0.043955 -0.006095 -0.017315      -0.001108
# ch_spinrate          0.000101 -0.050283 -0.014055 -0.001986       0.007110
# ch_hb                0.026197 -0.194854 -0.057747  0.032134       0.042687
# ch_vb               -0.046453  0.055686  0.075843 -0.033238      -0.060860
# ch_brk              -0.020867 -0.076791  0.006403 -0.010984      -0.008619
# ch_velo_range       -0.001641 -0.032623 -0.016391 -0.009575       0.024355
# cb%                  0.108876  0.084724 -0.106144  0.106624       0.081164
# cb_velo              0.188564  0.075075 -0.180553  0.182031       0.185108
# cb_spinrate          0.202364  0.097410 -0.190994  0.186078       0.192410
# cb_hb                0.089905  0.299013 -0.064428  0.070014       0.077951
# cb_vb               -0.210946 -0.087053  0.211519 -0.203221      -0.213619
# cb_brk               0.210171  0.126050 -0.211506  0.181146       0.206084
# cb_velo_range        0.170569  0.071334 -0.172165  0.161849       0.192691
# cu%                  0.743235  0.286031 -0.709123  0.697233       0.723524
# cu_velo              0.994007  0.318529 -0.970305  0.938300       0.959754
# cu_spinrate          1.000000  0.342281 -0.970732  0.929465       0.959607
# cu_hb                0.342281  1.000000 -0.311742  0.284839       0.344658
# cu_vb               -0.970732 -0.311742  1.000000 -0.852184      -0.958410
# cu_brk               0.929465  0.284839 -0.852184  1.000000       0.872993
# cu_velo_range        0.959607  0.344658 -0.958410  0.872993       1.000000
# xops                 0.024916 -0.019627 -0.029713  0.050017       0.019329
#
#                       xops
# throws           -0.003748
# n_pitches         0.014941
# 4seam%           -0.050360
# 4seam_velo       -0.026849
# 4seam_spinrate   -0.065794
# 4seam_hb          0.021264
# 4seam_vb         -0.126535
# 4seam_brk        -0.056624
# 4seam_velo_range  0.104675
# sl%              -0.111618
# sl_velo          -0.032253
# sl_spinrate      -0.054873
# sl_hb             0.003166
# sl_vb             0.032590
# sl_brk           -0.137110
# sl_velo_range    -0.004822
# ch%               0.124396
# ch_velo           0.176248
# ch_spinrate       0.148300
# ch_hb            -0.004654
# ch_vb            -0.204227
# ch_brk            0.139411
# ch_velo_range     0.213455
# cb%               0.064230
# cb_velo           0.180255
# cb_spinrate       0.154401
# cb_hb             0.020279
# cb_vb            -0.190209
# cb_brk            0.101020
# cb_velo_range     0.182267
# cu%               0.017657
# cu_velo           0.035899
# cu_spinrate       0.024916
# cu_hb            -0.019627
# cu_vb            -0.029713
# cu_brk            0.050017
# cu_velo_range     0.019329
# xops              1.000000
#
# [38 rows x 38 columns]

# %%
sns.pairplot(data = data, x_vars = velo, 
             y_vars = ['xba']);

# %%
sns.pairplot(data = data, x_vars = velo, 
             y_vars = ['xslg']);

# %%
sns.pairplot(data = data, x_vars = velo, 
             y_vars = ['xops']);

# %%
sns.pairplot(data = data, x_vars = spin, 
             y_vars = ['z_swing%']);

# %%
sns.pairplot(data = data, x_vars = spin, 
             y_vars = ['z_swing_miss%']);

# %%
sns.pairplot(data = data, x_vars = spin, 
             y_vars = ['oz_swing%']);

# %%
sns.pairplot(data = data, x_vars = spin, 
             y_vars = ['oz_swing_miss%']);

# %% [markdown]
# # Visuals

# %%
fig, ax = plt.subplots(5, 2, figsize = (20, 35))

ax[0][0].hist(data['4seam_velo'], color = 'navy')
ax[0][0].axvline(x = data['4seam_velo'].mean(), color = 'yellow', label = 'average 4seam velocity')
ax[0][0].set_xlabel('velocity', fontsize = 12)
ax[0][0].set_ylabel('n pitches', fontsize = 12)
ax[0][0].set_title('4seam Velocity', fontsize = 14, fontweight = 'bold', pad = 12)
ax[0][0].legend()

ax[0][1].hist(data['4seam_spinrate'], color = 'skyblue')
ax[0][1].axvline(x = data['4seam_spinrate'].mean(), color = 'r', label = 'average 4seam spin rate')
ax[0][1].set_xlabel('spin rate', fontsize = 12)
ax[0][1].set_ylabel('n pitches', fontsize = 12)
ax[0][1].set_title('4seam Spin Rate', fontsize = 14, fontweight = 'bold', pad = 12)
ax[0][1].legend()

ax[1][0].hist(data['sl_velo'], color = 'mediumblue')
ax[1][0].axvline(x = data['sl_velo'].mean(), color = 'r', label = 'average sl velocity')
ax[1][0].set_xlabel('velocity', fontsize = 12)
ax[1][0].set_ylabel('n pitches', fontsize = 12)
ax[1][0].set_title('Slider Velocity', fontsize = 14, fontweight = 'bold', pad = 12)
ax[1][0].legend()

ax[1][1].hist(data['sl_spinrate'], color = 'lightblue')
ax[1][1].axvline(x = data['sl_spinrate'].mean(), color = 'r', label = 'average sl spin rate')
ax[1][1].set_xlabel('spin rate', fontsize = 12)
ax[1][1].set_ylabel('n pitches', fontsize = 12)
ax[1][1].set_title('Slider Spin Rate', fontsize = 14, fontweight = 'bold', pad = 12)
ax[1][1].legend()

ax[2][0].hist(data['cb_velo'], color = 'royalblue')
ax[2][0].axvline(x = data['cb_velo'].mean(), color = 'r', label = 'average cb velocity')
ax[2][0].set_xlabel('velocity', fontsize = 12)
ax[2][0].set_ylabel('n pitches', fontsize = 12)
ax[2][0].set_title('Curveball Velocity', fontsize = 14, fontweight = 'bold', pad = 12)
ax[2][0].legend()

ax[2][1].hist(data['cb_spinrate'], color = 'red')
ax[2][1].axvline(x = data['cb_spinrate'].mean(), color = 'k', label = 'average cb spin rate')
ax[2][1].set_xlabel('spin rate', fontsize = 12)
ax[2][1].set_ylabel('n pitches', fontsize = 12)
ax[2][1].set_title('Curveball Spin Rate', fontsize = 14, fontweight = 'bold', pad = 12)
ax[2][1].legend()

ax[3][0].hist(data['ch_velo'], color = 'lightsteelblue')
ax[3][0].axvline(x = data['ch_velo'].mean(), color = 'r', label = 'average ch velocity')
ax[3][0].set_xlabel('velocity', fontsize = 12)
ax[3][0].set_ylabel('n pitches', fontsize = 12)
ax[3][0].set_title('Change-up Velocity', fontsize = 14, fontweight = 'bold', pad = 12)
ax[3][0].legend()

ax[3][1].hist(data['ch_spinrate'], color = 'orange')
ax[3][1].axvline(x = data['ch_spinrate'].mean(), color = 'b', label = 'average ch spin rate')
ax[3][1].set_xlabel('spin rate', fontsize = 12)
ax[3][1].set_ylabel('n pitches', fontsize = 12)
ax[3][1].set_title('Change-up Spin Rate', fontsize = 14, fontweight = 'bold', pad = 12)
ax[3][1].legend()

ax[4][0].hist(data['cu_velo'], color = 'powderblue')
ax[4][0].axvline(x = data['cu_velo'].mean(), color = 'r', label = 'average cu velocity')
ax[4][0].set_xlabel('velocity.', fontsize = 12)
ax[4][0].set_ylabel('n pitches', fontsize = 12)
ax[4][0].set_title('Cutter Velocity', fontsize = 14, fontweight = 'bold', pad = 12)
ax[4][0].legend()

ax[4][1].hist(data['cu_spinrate'], color = 'lightblue')
ax[4][1].axvline(x = data['cu_spinrate'].mean(), color = 'r', label = 'average cu spin rate')
ax[4][1].set_xlabel('spin rate', fontsize = 12)
ax[4][1].set_ylabel('n pitches', fontsize = 12)
ax[4][1].set_title('Cutter Spin Rate', fontsize = 14, fontweight = 'bold', pad = 12)
ax[4][1].legend();

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].bar(data['4seam_velo'], data['z_swing_miss%'], color = 'navy')
ax[0].set_xlabel('velocity', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('4 Seam Velocity In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].bar(data['4seam_velo'], data['oz_swing_miss%'], color = 'navy')
ax[1].set_xlabel('velocity', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('4 Seam Velocity Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

#plt.savefig('4seam velo swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].hist2d(pitch_data['4seam_spinrate'], pitch_data['z_swing_miss%'], cmap = 'coolwarm')
ax[0].set_xlabel('spin rate', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('4 Seam Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].hist2d(pitch_data['4seam_spinrate'], pitch_data['oz_swing_miss%'], cmap = 'coolwarm')
ax[1].set_xlabel('spin rate', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('4 Seam Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

#plt.savefig('4seam spin rate swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].bar(pitch_data['sl_velo'], pitch_data['z_swing_miss%'], color = 'lightblue')
ax[0].set_xlabel('velocity', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('Slider Velocity In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].bar(pitch_data['sl_velo'], pitch_data['oz_swing_miss%'], color = 'lightblue')
ax[1].set_xlabel('velocity', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('Slider Velocity Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

#plt.savefig('slider velo swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].hist2d(pitch_data['sl_spinrate'], pitch_data['z_swing_miss%'], cmap = 'coolwarm')
ax[0].set_xlabel('spin rate', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('Slider Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].hist2d(pitch_data['sl_spinrate'], pitch_data['oz_swing_miss%'], cmap = 'coolwarm')
ax[1].set_xlabel('spin rate', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('Slider Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

#plt.savefig('slider spin rate swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].hist2d(pitch_data['cb_spinrate'], pitch_data['z_swing_miss%'], cmap = 'coolwarm')
ax[0].set_xlabel('spin rate', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('Curveball Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].hist2d(pitch_data['cb_spinrate'], pitch_data['oz_swing_miss%'], cmap = 'coolwarm')
ax[1].set_xlabel('spin rate', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('Curveball Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

#plt.savefig('Curveball spin rate swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].hist2d(pitch_data['ch_spinrate'], pitch_data['z_swing_miss%'], cmap = 'coolwarm')
ax[0].set_xlabel('spin rate', fontsize = 12)
ax[0].set_ylabel('in-zone swing and miss', fontsize = 12)
ax[0].set_title('Changeup Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].hist2d(pitch_data['ch_spinrate'], pitch_data['oz_swing_miss%'], cmap = 'coolwarm')
ax[1].set_xlabel('spin rate', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('Changeup Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

#plt.savefig('Changeup spin rate swing and miss.png')

# %%
fig, ax = plt.subplots(1, 2, figsize = (20, 8))

ax[0].stem(data['4seam_velo'], data['ev_avg'])
ax[0].set_xlabel('velocity', fontsize = 12)
ax[0].set_ylabel('exit velocity', fontsize = 12)
ax[0].set_title('4seam Velocity Exit Velocity', fontsize = 14, fontweight = 'bold', pad = 12)

ax[1].stem(data['4seam_velo'], data['oz_swing_miss%'])
ax[1].set_xlabel('velocity', fontsize = 12)
ax[1].set_ylabel('out of zone swing and miss', fontsize = 12)
ax[1].set_title('4seam Velocity Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

plt.scatter(x = data['4seam_spinrate'],y = data['z_swing_miss%'], color = 'navy')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('in-zone swing and miss', fontsize = 12)
plt.title('4seam Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['sl_spinrate'],y = data['z_swing_miss%'], color = 'mediumblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('in-zone swing and miss', fontsize = 12)
plt.title('Slider Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['cb_spinrate'],y = data['z_swing_miss%'], color = 'lightsteelblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('in-zone swing and miss', fontsize = 12)
plt.title('Curveball Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['ch_spinrate'],y = data['z_swing_miss%'], color = 'red')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('in-zone swing and miss', fontsize = 12)
plt.title('Change-up Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['cu_spinrate'],y = data['z_swing_miss%'], color = 'skyblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('in-zone swing and miss', fontsize = 12)
plt.title('Cutter Spin Rate In-Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['4seam_spinrate'],y = data['oz_swing_miss%'], color = 'navy')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('out of zone swing and miss', fontsize = 12)
plt.title('4 Seam Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['sl_spinrate'],y = data['oz_swing_miss%'], color = 'mediumblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('out of zone swing and miss', fontsize = 12)
plt.title('Slider Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['cb_spinrate'],y = data['oz_swing_miss%'], color = 'lightsteelblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('out of zone swing and miss', fontsize = 12)
plt.title('Curveball Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['ch_spinrate'],y = data['oz_swing_miss%'], color = 'red')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('out of zone swing and miss', fontsize = 12)
plt.title('Change-up Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);

# %%
plt.figure(figsize = (8, 8))

sns.scatterplot(x = data['cu_spinrate'],y = data['oz_swing_miss%'], color = 'skyblue')
plt.xlabel('spin rate', fontsize = 12)
plt.ylabel('out of zone swing and miss', fontsize = 12)
plt.title('Cutter Spin Rate Out of Zone Swing and Miss', fontsize = 14, fontweight = 'bold', pad = 12);
