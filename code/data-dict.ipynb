# %%
import pandas as pd

# %%
pitch = pd.read_csv('../datasets/mlb_pitch_stats_19_21.csv')

pitch_columns_dict = {
    'player_age': 'age', 'p_formatted_ip': 'ip', 'p_total_pa': 'bf', 'p_ab': 'ab', 'p_total_hits': 'h',
    'p_k_percent': 'k%', 'p_bb_percent': 'bb%', 'batting_avg': 'ba', 'slg_percent': 'slg%', 
    'on_base_percent': 'obp%', 'on_base_plus_slg': 'ops','p_earned_run': 'earned_runs', 
    'p_era': 'era', 'p_quality_start': 'qual_start', 'p_complete_game': 'cg', 'exit_velocity_avg': 'ev_avg', 
    'launch_angle_avg': 'la_avg', 'sweet_spot_percent': 'sweet_spot%', 'barrel_batted_rate': 'barrel%', 
    'solidcontact_percent': 'solid_contact%', 'poorlyweak_percent': 'poor_weak%', 
    'hard_hit_percent': 'hard_hit%', 'z_swing_percent': 'z_swing%', 'z_swing_miss_percent': 'z_swing_miss%', 
    'oz_swing_percent': 'oz_swing%', 'oz_swing_miss_percent': 'oz_swing_miss%', 
    'oz_contact_percent': 'oz_contact%', 'out_zone_percent': 'out_zone%', 'iz_contact_percent': 'z_contact%', 
    'in_zone_percent': 'in_zone%', 'edge_percent': 'edge%', 'whiff_percent': 'whiff%', 
    'swing_percent': 'swing%', 'groundballs_percent': 'gb%', 'flyballs_percent': 'fb%', 
    'linedrives_percent': 'ld%', 'popups_percent': 'po%', 'pitch_hand': 'throws', 'n': 'n_pitches', 
    # 4-seam
    'n_ff_formatted': '4seam%', 'ff_avg_speed': '4seam_velo', 'ff_avg_spin': '4seam_spinrate', 
    'ff_avg_break_x': '4seam_hb', 'ff_avg_break_z': '4seam_vb', 'ff_avg_break': '4seam_brk', 
    'ff_range_speed': '4seam_velo_range', 
    # slider
    'n_sl_formatted': 'sl%', 'sl_avg_speed': 'sl_velo', 'sl_avg_spin': 'sl_spinrate', 
    'sl_avg_break_x': 'sl_hb', 'sl_avg_break_z': 'sl_vb', 'sl_avg_break': 'sl_brk', 
    'sl_range_speed': 'sl_velo_range', 
    # changeup
    'n_ch_formatted': 'ch%', 'ch_avg_speed': 'ch_velo', 'ch_avg_spin': 'ch_spinrate', 
    'ch_avg_break_x': 'ch_hb', 'ch_avg_break_z': 'ch_vb', 'ch_avg_break': 'ch_brk', 
    'ch_range_speed': 'ch_velo_range', 
    # curveball
    'n_cukc_formatted': 'cb%', 'cu_avg_speed': 'cb_velo', 'cu_avg_spin': 'cb_spinrate', 
    'cu_avg_break_x': 'cb_hb', 'cu_avg_break_z': 'cb_vb', 'cu_avg_break': 'cb_brk', 
    'cu_range_speed': 'cb_velo_range', 
    # cutter
    'n_fc_formatted': 'cu%', 'fc_avg_speed': 'cu_velo', 'fc_avg_spin': 'cu_spinrate', 
    'fc_avg_break_x': 'cu_hb', 'fc_avg_break_z': 'cu_vb', 'fc_avg_break': 'cu_brk', 
    'fc_range_speed': 'cu_velo_range', 
    # 2-seam
    'n_fastball_formatted': '2seam%', 'fastball_avg_speed': '2seam_velo', 
    'fastball_avg_spin': '2seam_spinrate', 'fastball_avg_break_x': '2seam_hb', 
    'fastball_avg_break_z': '2seam_vb', 'fastball_avg_break': '2seam_brk', 
    'fastball_range_speed': '2seam_velo_range'
}
pitch.rename(columns = pitch_columns_dict, inplace = True)
pitch.drop(columns = ['Unnamed: 97', 'xbadiff', 'wobadif', '2seam%', '2seam_velo', 
                      '2seam_spinrate', '2seam_hb', '2seam_vb', '2seam_brk', '2seam_velo_range'], 
           inplace = True)
print(pitch.shape)

pitch_2 = pd.read_csv('../datasets/mlb_pitch_stats_20.csv')

pitch_2.rename(columns = pitch_columns_dict, inplace=True)
pitch_2.drop(columns = ['Unnamed: 97', 'xbadiff', 'wobadif', '2seam%', '2seam_velo', 
                       '2seam_spinrate', '2seam_hb', '2seam_vb', '2seam_brk', '2seam_velo_range'], 
             inplace = True)
print(pitch_2.shape)
# Out:
# (704, 88)
# (368, 88)

# %%
spin = pd.read_csv('../datasets/mlb_fb_spin_direction_21.csv')  
# index_col = 'player_id')

spin.year.fillna(2020, inplace = True)
spin.drop(columns = ['api_pitch_type'], inplace = True)

spin_columns_dict = {
    'pitch_hand': 'throws',
    'api_pitch_name': 'pitch',
    'release_speed': 'velo',
    #'diff_measured_inferred_minutes': 'obs_dev_diff',
    'hawkeye_measured_clock_hh': 'spin_based_dir_hh',
    'hawkeye_measured_clock_mm': 'spin_based_dir_mm',
    'movement_inferred_clock_hh': 'observed_dir_hh',
    'movement_inferred_clock_mm': 'observed_dir_mm',
    'diff_clock_hh': 'obs_dev_diff_hh',
    'diff_clock_mm': 'obs_dev_diff_mm'
}

spin.rename(columns = spin_columns_dict, inplace = True)
print(spin.shape)
# Out:
# (448, 29)

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# |Feature          |Type     |Dataset                     |Description                |
# |---              |---      |---                         |---                        |
# |player_id        |int64    |mlb_pitch_stats_19_21, 20   |player ID                  |
# |last_name        |object   |mlb_pitch_stats_19_21, 20   |player last name           |
# |first_name       |object   |mlb_pitch_stats_19_21, 20   |player first name          |
# |year             |int64    |mlb_pitch_stats_19_21, 20   |season                     |
# |age              |int64    |mlb_pitch_stats_19_21, 20   |players's age              |
# |ip               |float64  |mlb_pitch_stats_19_21, 20   |number of innings pitched  |
# |bf               |int64    |mlb_pitch_stats_19_21, 20   |number of innings pitched  |
# |ab               |int64    |mlb_pitch_stats_19_21, 20   |number of innings pitched  |
# |h                |int64    |mlb_pitch_stats_19_21, 20   |hits given up  |
# |k%               |float64  |mlb_pitch_stats_19_21, 20   |strikeout percentage       |
# |bb%              |float64  |mlb_pitch_stats_19_21, 20   |walk percentage            |
# |ba               |float64  |mlb_pitch_stats_19_21, 20   |batting average against    |
# |slg%             |float64  |mlb_pitch_stats_19_21, 20   |slugging percentage against       |
# |obp%             |float64  |mlb_pitch_stats_19_21, 20   |on base percentage         |
# |ops              |float64  |mlb_pitch_stats_19_21, 20   |on base plus slugging against  |
# |earned_runs      |int64    |mlb_pitch_stats_19_21, 20   |earned runs   |
# |era              |float64  |mlb_pitch_stats_19_21, 20   |earned run average  |
# |qual_start       |int64    |mlb_pitch_stats_19_21, 20   |quality start (>= 6 ip <= 3 runs) |
# |cg               |int64    |mlb_pitch_stats_19_21, 20   |complete game  |
# |xba              |float64  |mlb_pitch_stats_19_21, 20   |expected ba (probability a batted ball will be a hit) |
# |xslg             |float64  |mlb_pitch_stats_19_21, 20   |expected slugging percentage  |
# |woba             |float64  |mlb_pitch_stats_19_21, 20   |weighted on-base average  |
# |xwoba            |float64  |mlb_pitch_stats_19_21, 20   |expected weighted on-base average |
# |xobp             |float64  |mlb_pitch_stats_19_21, 20   |expected on-base percentage  |
# |wobacon          |float64  |mlb_pitch_stats_19_21, 20   |  |
# |xwobacon         |float64  |mlb_pitch_stats_19_21, 20   |  |
# |bacon            |float64  |mlb_pitch_stats_19_21, 20   |batting avgerage on contact  |
# |xbacon           |float64  |mlb_pitch_stats_19_21, 20   |expected batting avgerage on contact   |
# |ev_avg           |float64  |mlb_pitch_stats_19_21, 20   |average exit velocity   |
# |la_avg           |float64  |mlb_pitch_stats_19_21, 20   |average LA (how high, in degrees, a ball was hit) |
# |sweet_spot%      |float64  |mlb_pitch_stats_19_21, 20   |batted ball with la between 8 and 32 degrees  |
# |barrel%          |float64  |mlb_pitch_stats_19_21, 20   |perfect combination of exit velocity and launch angle |
# |solid_contact%   |float64  |mlb_pitch_stats_19_21, 20   |solid contact percentage  |
# |poor_weak%       |float64  |mlb_pitch_stats_19_21, 20   |poor/weak contact percentage  |
# |hard_hit%        |float64  |mlb_pitch_stats_19_21, 20   |exit velo > 95 mph hard hit ball percentage     |
# |z_swing%         |float64  |mlb_pitch_stats_19_21, 20   |in-zone swing percentage  |
# |z_swing_miss%    |float64  |mlb_pitch_stats_19_21, 20   |in-zone swing and miss percentage  |
# |oz_swing%        |float64  |mlb_pitch_stats_19_21, 20   |out-zone swing percentage  |
# |oz_swing_miss%   |float64  |mlb_pitch_stats_19_21, 20   |out-zone swing and miss percentage   |
# |oz_contact%      |float64  |mlb_pitch_stats_19_21, 20   |out-zone contact percentage  |
# |out_zone%        |float64  |mlb_pitch_stats_19_21, 20   |out_zone percentage  |
# |pitch_count      |int64    |mlb_pitch_stats_19_21, 20   |pitch count   |
# |z_contact%       |float64  |mlb_pitch_stats_19_21, 20   |in-zone contact percentage   |
# |in_zone%         |float64  |mlb_pitch_stats_19_21, 20   |in-zone percentage  |
# |edge%            |float64  |mlb_pitch_stats_19_21, 20   |edge of zone percentage  |
# |whiff%           |float64  |mlb_pitch_stats_19_21, 20   |whiff percentage   |
# |swing%           |float64  |mlb_pitch_stats_19_21, 20   |swing percentage   |
# |gb%              |float64  |mlb_pitch_stats_19_21, 20   |ground ball percentage  |
# |fb%              |float64  |mlb_pitch_stats_19_21, 20   |fly ball percentage   |
# |ld%              |float64  |mlb_pitch_stats_19_21, 20   |line drive percentage   |
# |po%              |float64  |mlb_pitch_stats_19_21, 20   |popup percentage   |
# |throws           |object   |mlb_pitch_stats_19_21, 20   |handedness                |
# |n_pitches        |int64    |mlb_pitch_stats_19_21, 20   |number of pitches thrown        |
# |4seam%           |float64  |mlb_pitch_stats_19_21, 20   |4seam fastball percentage thrown       |
# |4seam_velo_avg   |float64  |mlb_pitch_stats_19_21, 20   |avgerage 4seam velocity       |
# |4seam_spin_avg   |float64  |mlb_pitch_stats_19_21, 20   |avgerage 4seam spinrate       |
# |4seam_hb_avg     |float64  |mlb_pitch_stats_19_21, 20   |avgerage 4seam horizontal break        |
# |4seam_vb_avg     |float64  |mlb_pitch_stats_19_21, 20   |avgerage 4seam vertical break        |
# |4seam_break_avg  |float64  |mlb_pitch_stats_19_21, 20   |avgerage 4seam total break        |
# |4seam_velo_range |float64  |mlb_pitch_stats_19_21, 20   |4seam velocity range       |
# |sl%              |float64  |mlb_pitch_stats_19_21, 20   |slider percentage thrown      |
# |sl_velo_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage sl velocity       |
# |sl_spin_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage sl spinrate         |
# |sl_hb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage sl horizontal break       |
# |sl_vb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage sl vertical break        |
# |sl_break_avg     |float64  |mlb_pitch_stats_19_21, 20   |avgerage sl total break       |
# |sl_velo_range    |float64  |mlb_pitch_stats_19_21, 20   |sl velocity range       |
# |ch%              |float64  |mlb_pitch_stats_19_21, 20   |changeup percentage thrown        |
# |ch_velo_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage ch velocity       |
# |ch_spin_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage ch spinrate       |
# |ch_hb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage ch horizontal break       |
# |ch_vb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage ch vertical break        |
# |ch_brk_avg       |float64  |mlb_pitch_stats_19_21, 20   |avgerage ch total break       |
# |ch_velo_range    |float64  |mlb_pitch_stats_19_21, 20   |ch velocity range       |
# |cb%              |float64  |mlb_pitch_stats_19_21, 20   |curveball percentage thrown       |
# |cb_velo_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage cb velocity       |
# |cb_spin_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage cb spinrate       |
# |cb_hb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage cb horizontal break        |
# |cb_vb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage cb vertical break        |
# |cb_brk_avg       |float64  |mlb_pitch_stats_19_21, 20   |avgerage cb total break         |
# |cb_velo_range    |float64  |mlb_pitch_stats_19_21, 20   |cb velocity range       |
# |cu%              |float64  |mlb_pitch_stats_19_21, 20   |cutter percentage thrown       |
# |cu_velo_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage cu velocity       |
# |cu_spin_avg      |float64  |mlb_pitch_stats_19_21, 20   |avgerage cu spinrate        |
# |cu_hb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage cu horizontal break        |
# |cu_vb_avg        |float64  |mlb_pitch_stats_19_21, 20   |avgerage cu vertical break        |
# |cu_brk_avg       |float64  |mlb_pitch_stats_19_21, 20   |avgerage cu total break        |
# |cu_velo_range    |float64  |mlb_pitch_stats_19_21, 20   |cu velocity range       |
# |2seam%           |float64  |mlb_pitch_stats_19_21, 20   |2seam percentage thrown       |
# |2seam_velo_avg   |float64  |mlb_pitch_stats_19_21, 20   |avgerage 2seam velocity        |
# |2seam_spin_avg   |int64    |mlb_pitch_stats_19_21, 20   |avgerage 2seam spinrate        |
# |2seam_hb_avg     |float64  |mlb_pitch_stats_19_21, 20   |avgerage 2seam horizontal break        |
# |2seam_vb_avg     |float64  |mlb_pitch_stats_19_21, 20   |avgerage 2seam vertical break        |
# |2seam_brk_avg    |float64  |mlb_pitch_stats_19_21, 20   |avgerage 2seam total break        |
# |2seam_velo_range |float64  |mlb_pitch_stats_19_21, 20   |2seam velocity range       |
# |year                           |float64   |mlb_fb_spin_direction_21  |season                     |
# |last_name                      |object    |mlb_fb_spin_direction_21  |player last name           |
# |first_name                     |object    |mlb_fb_spin_direction_21  |player first name          |
# |player_id                      |int64     |mlb_fb_spin_direction_21  |player ID                  |
# |throws                         |object    |mlb_fb_spin_direction_21  |handedness                 |
# |n_pitches                      |int64     |mlb_fb_spin_direction_21  |number of pitches thrown   |
# |velo                           |float64   |mlb_fb_spin_direction_21  |avgerage fb velocity       |
# |spinrate                       |int64     |mlb_fb_spin_direction_21  |avgerage fb spinrate       |
# |movement_inches                |float64   |mlb_fb_spin_direction_21  |avgerage fb break in inches |
# |alan_active_spin_pct           |float64   |mlb_fb_spin_direction_21  |alan active spin        |
# |active_spin                    |float64   |mlb_fb_spin_direction_21  |active spin        |
# |hawkeye_measured               |float64   |mlb_fb_spin_direction_21  |hawkeye       |
# |movement_inferred              |float64   |mlb_fb_spin_direction_21  |movement       |
# |pitch                          |object    |mlb_fb_spin_direction_21  |pitch      |
# |active_spin_formatted          |int64     |mlb_fb_spin_direction_21  |active spin      |
# |hawkeye_measured_clock_minutes |int64     |mlb_fb_spin_direction_21  |hawkeye        |
# |movement_inferred_clock_minutes|int64     |mlb_fb_spin_direction_21  |movement |
# |diff_measured_inferred         |float64   |mlb_fb_spin_direction_21  |inferred       |
# |diff2                          |float64   |mlb_fb_spin_direction_21  |difference       |
# |diff_measured_inferred_minutes |int64     |mlb_fb_spin_direction_21  |difference clock minutes      |
# |spin_based_dir_hh              |int64     |mlb_fb_spin_direction_21  |spin direction clock hours       |
# |spin_based_dir_mm              |int64     |mlb_fb_spin_direction_21  |spin direction clock minutes       |
# |observed_dir_hh                |int64     |mlb_fb_spin_direction_21  |spin direction clock hours        |
# |observed_dir_mm                |int64     |mlb_fb_spin_direction_21  |spin direction clock minutes       |
# |obs_dev_diff_hh                |int64     |mlb_fb_spin_direction_21  |observed deviation difference clock hours |
# |obs_dev_diff_mm                |int64     |mlb_fb_spin_direction_21  |observed deviation difference clock hours |
# |hawkeye_measured_clock_label   |object    |mlb_fb_spin_direction_21  |hawkeye       |
# |movement_inferred_clock_label  |object    |mlb_fb_spin_direction_21  |movement inferred       |
# |diff_clock_label               |object    |mlb_fb_spin_direction_21  |difference clock label       |

# %% [markdown]
# # Export Datasets

# %%
pitch.to_csv('../datasets/mlb_pitch_stats_19_21_cleaned.csv')
pitch_2.to_csv('../datasets/mlb_pitch_stats_20_cleaned.csv')
spin.to_csv('../datasets/mlb_fb_spin_direction_21_cleaned.csv')
