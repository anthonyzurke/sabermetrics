# %% [markdown]
# # Libraries

# %%
import pandas as pd

# %% [markdown]
# # Data

# %%
pitch = pd.read_csv('../data/mlb pitch data 18-21.csv')       # index_col = 'last_name')
pitch.drop(columns = ['Unnamed: 48'], inplace = True)
print(pitch.shape)
# Out:
# (2040, 48)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Rename Columns

# %%
new_columns_dict = {
    'player_age': 'age', 'p_formatted_ip': 'ip', 'p_k_percent': 'k%', 'p_bb_percent': 'bb%',
    'batting_avg': 'ba_against', 'slg_percent': 'slg_against', 'on_base_plus_slg': 'ops_against',
    'pitch_hand': 'throws', 'n': 'n_pitches', 'n_ff_formatted': '4seam%', 'ff_avg_speed': '4seam_avg_velo',
    'ff_avg_spin': '4seam_avg_spinrate', 'ff_avg_break_x': '4seam_avg_hb', 'ff_avg_break_z': '4seam_avg_vb',
    'ff_avg_break': '4seam_avg_break', 'ff_range_speed': '4seam_velo_range', 'n_sl_formatted': 'sl%',
    'sl_avg_speed': 'sl_avg_velo', 'sl_avg_spin': 'sl_avg_spinrate', 'sl_avg_break_x': 'sl_avg_hb',
    'sl_avg_break_z': 'sl_avg_vb', 'sl_avg_break': 'sl_avg_break', 'sl_range_speed': 'sl_velo_range',
    'n_ch_formatted': 'ch%', 'ch_avg_speed': 'ch_avg_velo', 'ch_avg_spin': 'ch_avg_spinrate',
    'ch_avg_break_x': 'ch_avg_hb', 'ch_avg_break_z': 'ch_avg_vb', 'ch_avg_break': 'ch_avg_break',
    'ch_range_speed': 'ch_velo_range', 'n_cukc_formatted': 'cb%', 'cu_avg_speed': 'ch_avg_velo',
    'cu_avg_spin': 'ch_avg_spinrate', 'cu_avg_break_x': 'ch_avg_hb', 'cu_avg_break_z': 'ch_avg_vb',
    'cu_avg_break': 'ch_avg_break', 'cu_range_speed': 'ch_velo_range', 'n_fc_formatted': 'cu%',
    'fc_avg_speed': 'cu_avg_velo', 'fc_avg_spin': 'cu_avg_spinrate', 'fc_avg_break_x': 'cu_avg_hb',
    'fc_avg_break_z': 'cu_avg_vb', 'fc_avg_break': 'cu_avg_break', 'fc_range_speed': 'cu_velo_range'
}

pitch.rename(columns = new_columns_dict, inplace=True)
pitch.head()
# Out:
#     last_name  first_name  player_id  year  age    ip    k%   bb%  ba_against  \
# 0  Wainwright        Adam     425794  2020   39  65.2  20.6   5.7       0.221
# 1     Greinke        Zack     425844  2020   37  67.0  24.5   3.3       0.256
# 2       Petit    Yusmeiro     433589  2020   36  21.2  19.3   5.7       0.232
# 3     Sanchez      Anibal     434671  2020   36  53.0  17.6   7.3       0.313
# 4      Rondon      Hector     444468  2020   32  20.0  23.7  11.3       0.298
#
#    slg_against  ...  ch_avg_vb ch_avg_break  ch_velo_range   cu%  cu_avg_velo  \
# 0        0.369  ...      -65.5         22.0            1.6  22.9         85.0
# 1        0.405  ...      -66.6         15.4            2.3   NaN          NaN
# 2        0.366  ...      -50.4         13.3            1.4  28.6         84.4
# 3        0.536  ...      -48.6          4.7            1.6  21.0         87.3
# 4        0.631  ...        NaN          NaN            NaN   NaN          NaN
#
# ...

# %%
pitch.dtypes
# Out:
# last_name              object
#  first_name            object
# player_id               int64
# year                    int64
# age                     int64
# ip                    float64
# k%                    float64
# bb%                   float64
# ba_against            float64
# slg_against           float64
# ops_against           float64
# throws                 object
# n_pitches               int64
# 4seam%                float64
# 4seam_avg_velo        float64
# 4seam_avg_spinrate    float64
# 4seam_avg_hb          float64
# 4seam_avg_vb          float64
# 4seam_avg_break       float64
# 4seam_velo_range      float64
# sl%                   float64
# sl_avg_velo           float64
# sl_avg_spinrate       float64
# sl_avg_hb             float64
# sl_avg_vb             float64
# sl_avg_break          float64
# sl_velo_range         float64
# ch%                   float64
# ch_avg_velo           float64
# ch_avg_spinrate       float64
# ch_avg_hb             float64
# ...

# %%
pitch.columns
# Out:
# Index(['last_name', ' first_name', 'player_id', 'year', 'age', 'ip', 'k%',
#        'bb%', 'ba_against', 'slg_against', 'ops_against', 'throws',
#        'n_pitches', '4seam%', '4seam_avg_velo', '4seam_avg_spinrate',
#        '4seam_avg_hb', '4seam_avg_vb', '4seam_avg_break', '4seam_velo_range',
#        'sl%', 'sl_avg_velo', 'sl_avg_spinrate', 'sl_avg_hb', 'sl_avg_vb',
#        'sl_avg_break', 'sl_velo_range', 'ch%', 'ch_avg_velo',
#        'ch_avg_spinrate', 'ch_avg_hb', 'ch_avg_vb', 'ch_avg_break',
#        'ch_velo_range', 'cb%', 'ch_avg_velo', 'ch_avg_spinrate', 'ch_avg_hb',
#        'ch_avg_vb', 'ch_avg_break', 'ch_velo_range', 'cu%', 'cu_avg_velo',
#        'cu_avg_spinrate', 'cu_avg_hb', 'cu_avg_vb', 'cu_avg_break',
#        'cu_velo_range'],
#       dtype='object')

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# |Feature            |Type      |Dataset               |Description                |
# |---                |---       |---                   |---                        |
# |last_name          |object    |mlb pitch data 18-21  |player last name           |
# |first_name         |object    |mlb pitch data 18-21  |player first name          |
# |player_id          |int64     |mlb pitch data 18-21  |player ID                  |
# |year               |int64     |mlb pitch data 18-21  |season                     |
# |age                |int64     |mlb pitch data 18-21  |players's age              |
# |ip                 |float64   |mlb pitch data 18-21  |number of innings pitched  |
# |k%                 |float64   |mlb pitch data 18-21  |strikeout percentage       |
# |bb%                |float64   |mlb pitch data 18-21  |walk percentage            |
# |ba_against         |float64   |mlb pitch data 18-21  |batting average against     |
# |slg_against        |float64   |mlb pitch data 18-21  |slugging percentage against       |
# |ops_against        |float64   |mlb pitch data 18-21  |on base plus slugging against  |
# |throws             |object    |mlb pitch data 18-21  |handedness                |
# |n_pitches          |int64     |mlb pitch data 18-21  |number of pitches thrown       |
# |4seam%             |float64   |mlb pitch data 18-21  |4 seam fastball percentage thrown       |
# |4seam_avg_velo     |float64   |mlb pitch data 18-21  |avgerage fb velocity       |
# |4seam_avg_spinrate |float64   |mlb pitch data 18-21  |avgerage fb spinrate       |
# |4seam_avg_hb       |float64   |mlb pitch data 18-21  |avgerage fb horizontal break       |
# |4seam_avg_vb       |float64   |mlb pitch data 18-21  |avgerage fb vertical break        |
# |4seam_avg_break    |float64   |mlb pitch data 18-21  |avgerage fb total break       |
# |4seam_velo_range   |float64   |mlb pitch data 18-21  |fb velocity range       |
# |sl%                |float64   |mlb pitch data 18-21  |slider percentage thrown      |
# |sl_avg_velo        |float64   |mlb pitch data 18-21  |avgerage sl velocity       |
# |sl_avg_spinrate    |float64   |mlb pitch data 18-21  |avgerage sl spinrate        |
# |sl_avg_hb          |float64   |mlb pitch data 18-21  |avgerage sl horizontal break       |
# |sl_avg_vb          |float64   |mlb pitch data 18-21  |avgerage sl vertical break       |
# |sl_avg_break       |float64   |mlb pitch data 18-21  |avgerage sl total break       |
# |sl_velo_range      |float64   |mlb pitch data 18-21  |sl velocity range       |
# |ch%                |float64   |mlb pitch data 18-21  |changeup percentage thrown       |
# |ch_avg_velo        |float64   |mlb pitch data 18-21  |avgerage ch velocity       |
# |ch_avg_spinrate    |float64   |mlb pitch data 18-21  |avgerage ch spinrate       |
# |ch_avg_hb          |float64   |mlb pitch data 18-21  |avgerage ch horizontal break       |
# |ch_avg_vb          |float64   |mlb pitch data 18-21  |avgerage ch vertical break       |
# |ch_avg_break       |float64   |mlb pitch data 18-21  |avgerage ch total break       |
# |ch_velo_range      |float64   |mlb pitch data 18-21  |ch velocity range       |
# |cb%                |float64   |mlb pitch data 18-21  |curveball percentage thrown       |
# |cb_avg_velo        |float64   |mlb pitch data 18-21  |avgerage cb velocity       |
# |cb_avg_spinrate    |float64   |mlb pitch data 18-21  |avgerage cb spinrate       |
# |cb_avg_hb          |float64   |mlb pitch data 18-21  |avgerage cb horizontal break        |
# |cb_avg_vb          |float64   |mlb pitch data 18-21  |avgerage cb vertical break       |
# |cb_avg_break       |float64   |mlb pitch data 18-21  |avgerage cb total break       |
# |cb_velo_range      |float64   |mlb pitch data 18-21  |cb velocity range       |
# |cu%                |float64   |mlb pitch data 18-21  |cutter percentage thrown       |
# |cu_avg_velo        |float64   |mlb pitch data 18-21  |avgerage cu velocity       |
# |cu_avg_spinrate    |float64   |mlb pitch data 18-21  |avgerage cu spinrate        |
# |cu_avg_hb          |float64   |mlb pitch data 18-21  |avgerage cu horizontal break        |
# |cu_avg_vb          |float64   |mlb pitch data 18-21  |avgerage cu vertical break       |
# |cu_avg_break       |float64   |mlb pitch data 18-21  |avgerage cu total break       |
# |cu_velo_range      |float64   |mlb pitch data 18-21  |cu velocity range       |

# %% [markdown]
# ### Check Nulls

# %% [markdown]
# #### if row has all nulls drop them, if row has some nulls use fillna()

# %%
pitch.isnull().sum()
# Out:
# last_name                0
#  first_name              0
# player_id                0
# year                     0
# age                      0
# ip                       0
# k%                       0
# bb%                      0
# ba_against               0
# slg%_against             0
# ops_against              0
# throws                   0
# n_pitches                0
# 4seam%                  93
# 4seam_avg_velo          93
# 4seam_avg_spinrate      93
# 4seam_avg_hb            93
# 4seam_avg_vb            93
# 4seam_avg_break         93
# 4seam_velo_range       113
# sl%                    486
# sl_avg_velo            486
# sl_avg_spinrate        486
# sl_avg_hb              486
# sl_avg_vb              486
# sl_avg_break           486
# sl_velo_range          495
# ch%                    418
# ch_avg_velo            418
# ch_avg_spinrate        418
# ch_avg_hb              418
# ch_avg_vb              418
# ch_avg_break           418
# ch_velo_range          462
# ...

# %% [markdown]
# ### Spin
